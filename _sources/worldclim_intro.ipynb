# %% [markdown]
# # Worldclim bioclimatic data

# %% [markdown]
# This section contains the worldclim elevation and bioclimatic data variables. Browse the variables using the menu on the left, or the next and previous buttons. Information on the variables can be found at https://www.worldclim.org/data/bioclim.html.
