# %% [markdown]
# # Bioclimatic data

# %% [markdown]
# This section contains bioclimatic data variables calculated from the ERA5-LAND reanalysis (see https://cds.climate.copernicus.eu/datasets/reanalysis-era5-land?tab=overview). The values are means for the years 1970-2005.
